# %%
# %load_ext autoreload
# %autoreload 2

# %%
from commando import ComManDo
import numpy as np
# Out:
# 2022-01-11 19:05:15.030934: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-11 19:05:15.030969: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
data1 = np.loadtxt("../data/Unioncom/MMD/s1_mapped1.txt")
data2 = np.loadtxt("../data/Unioncom/MMD/s1_mapped2.txt")
type1 = np.loadtxt("../data/Unioncom/MMD/s1_type1.txt")
type2 = np.loadtxt("../data/Unioncom/MMD/s1_type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)

# %% [markdown]
# # ComManDo

# %%
cm = ComManDo(aligned_idx=((),()))
cm_data = cm.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:4.5494 alpha:0.7759
# epoch:[200/2000] err:2.8128 alpha:0.5134
# epoch:[300/2000] err:2.7323 alpha:0.5466
# epoch:[400/2000] err:2.4531 alpha:0.5767
# epoch:[500/2000] err:1.9160 alpha:0.6219
# epoch:[600/2000] err:1.6819 alpha:0.6526
# epoch:[700/2000] err:1.5806 alpha:0.6709
# epoch:[800/2000] err:1.4751 alpha:0.6851
# epoch:[900/2000] err:1.3157 alpha:0.6997
# epoch:[1000/2000] err:1.2072 alpha:0.7121
# epoch:[1100/2000] err:1.1563 alpha:0.7209
# epoch:[1200/2000] err:1.1283 alpha:0.7277
# epoch:[1300/2000] err:1.1095 alpha:0.7334
# epoch:[1400/2000] err:1.0952 alpha:0.7383
# epoch:[1500/2000] err:1.0835 alpha:0.7428
# epoch:[1600/2000] err:1.0733 alpha:0.7468
# epoch:[1700/2000] err:1.0644 alpha:0.7504
# epoch:[1800/2000] err:1.0563 alpha:0.7536
# epoch:[1900/2000] err:1.0488 alpha:0.7566
# epoch:[2000/2000] err:1.0416 alpha:0.7592
# Finished Matching!
# ---------------------------------
# Performing NLMA
# epoch:[10/100]: loss:32.429058
# epoch:[20/100]: loss:27.635689
# epoch:[30/100]: loss:25.145458
# epoch:[40/100]: loss:22.932285
# epoch:[50/100]: loss:23.512430
# epoch:[60/100]: loss:19.348549
# epoch:[70/100]: loss:19.998096
# epoch:[80/100]: loss:16.803492
# epoch:[90/100]: loss:15.739269
# epoch:[100/100]: loss:16.475580
# Finished Mapping!
# Setup: 0.29119444000025396
# Get subset samples: 0.0022150091466604255
# Run model: 0.050733944986665544
# Reconstruction loss: 0.0002923877033117606
# Aligned loss: 0.00020809032999144015
# F-cross loss: 2.2397951653753504e-05
# Step: 0.24416524578999088
# Output: 0.18713337000008323
# Total: 0.775964885908611
# ---------------------------------
# ComManDo Done!
# Distance: 0.06689947199993185
# Correspondence: 4.043161288000192
# Mapping: 89.78484452300017
# Total: 93.8949052830003

# %%
cm.test_LabelTA(cm_data, [type1,type2])
cm.test_closer(cm_data)
cm.Visualize([data1,data2], cm_data, [type1,type2], mode='PCA')
# Out:
# label transfer accuracy of data1:
# 0.18666666666666668
# foscttm: 0.49635
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # UnionCom

# %%
uc = ComManDo(project_mode='tsne')
uc_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 2000)
# Dataset 1: (300, 1000)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:4.5494 alpha:0.7759
# epoch:[200/2000] err:2.8128 alpha:0.5134
# epoch:[300/2000] err:2.7323 alpha:0.5466
# epoch:[400/2000] err:2.4531 alpha:0.5767
# epoch:[500/2000] err:1.9160 alpha:0.6219
# epoch:[600/2000] err:1.6819 alpha:0.6526
# epoch:[700/2000] err:1.5806 alpha:0.6709
# epoch:[800/2000] err:1.4751 alpha:0.6851
# epoch:[900/2000] err:1.3157 alpha:0.6997
# epoch:[1000/2000] err:1.2072 alpha:0.7121
# epoch:[1100/2000] err:1.1563 alpha:0.7209
# epoch:[1200/2000] err:1.1283 alpha:0.7277
# epoch:[1300/2000] err:1.1095 alpha:0.7334
# epoch:[1400/2000] err:1.0952 alpha:0.7383
# epoch:[1500/2000] err:1.0835 alpha:0.7428
# epoch:[1600/2000] err:1.0733 alpha:0.7468
# epoch:[1700/2000] err:1.0644 alpha:0.7504
# epoch:[1800/2000] err:1.0563 alpha:0.7536
# epoch:[1900/2000] err:1.0488 alpha:0.7566
# epoch:[2000/2000] err:1.0416 alpha:0.7592
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:1.203351, align_loss:0.092578
# epoch:[20/100]: loss:1.005172, align_loss:0.085880
# epoch:[30/100]: loss:0.956179, align_loss:0.085275
# epoch:[40/100]: loss:0.925107, align_loss:0.094839
# epoch:[50/100]: loss:0.889321, align_loss:0.085566
# epoch:[60/100]: loss:0.798236, align_loss:0.103262
# epoch:[70/100]: loss:0.831913, align_loss:0.079937
# epoch:[80/100]: loss:0.772945, align_loss:0.085796
# epoch:[90/100]: loss:0.831937, align_loss:0.085652
# epoch:[100/100]: loss:0.844634, align_loss:0.078152
# Done
# ---------------------------------
# ComManDo Done!
# Distance: 0.12875805299972853
# Correspondence: 4.265113358000235
# Mapping: 3.9945762090001153
# Total: 8.388447620000079

# %%
uc.test_LabelTA(uc_data, [type1,type2])
uc.test_closer(uc_data)
uc.Visualize([data1,data2], uc_data, [type1,type2], mode='PCA')
# Out:
# label transfer accuracy of data1:
# 0.9166666666666666
# foscttm: 0.11015555555555556
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
