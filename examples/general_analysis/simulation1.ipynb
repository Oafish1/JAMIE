# %%
# %load_ext autoreload
# %autoreload 2

# %%
from commando import ComManDo
from commando.evaluation import generate_figure, test_partial
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# Out:
# 2022-03-02 02:41:30.132801: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-03-02 02:41:30.132833: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
data1 = np.loadtxt("../data/UnionCom/simu1/domain1.txt")
data2 = np.loadtxt("../data/UnionCom/simu1/domain2.txt")
type1 = np.loadtxt("../data/UnionCom/simu1/type1.txt")
type2 = np.loadtxt("../data/UnionCom/simu1/type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)
type_func = lambda x: x

# %% [markdown]
# # ComManDo Aligned

# %%
cm = ComManDo()
cm_data = cm.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:1.6447 alpha:0.6584
# epoch:[200/2000] err:1.0756 alpha:0.4405
# epoch:[300/2000] err:1.0785 alpha:0.4617
# epoch:[400/2000] err:1.0615 alpha:0.4804
# epoch:[500/2000] err:1.0320 alpha:0.4984
# epoch:[600/2000] err:0.9937 alpha:0.5168
# epoch:[700/2000] err:0.9436 alpha:0.5364
# epoch:[800/2000] err:0.8768 alpha:0.5580
# epoch:[900/2000] err:0.7976 alpha:0.5809
# epoch:[1000/2000] err:0.7222 alpha:0.6023
# epoch:[1100/2000] err:0.6627 alpha:0.6195
# epoch:[1200/2000] err:0.6187 alpha:0.6327
# epoch:[1300/2000] err:0.5845 alpha:0.6433
# epoch:[1400/2000] err:0.5559 alpha:0.6523
# epoch:[1500/2000] err:0.5306 alpha:0.6603
# epoch:[1600/2000] err:0.5071 alpha:0.6676
# epoch:[1700/2000] err:0.4846 alpha:0.6744
# epoch:[1800/2000] err:0.4634 alpha:0.6808
# epoch:[1900/2000] err:0.4434 alpha:0.6866
# epoch:[2000/2000] err:0.4250 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Performing NLMA
# epoch:[10/100]: loss:13.594101
# epoch:[20/100]: loss:11.572464
# epoch:[30/100]: loss:12.883839
# epoch:[40/100]: loss:9.459291
# epoch:[50/100]: loss:8.717750
# epoch:[60/100]: loss:7.910768
# epoch:[70/100]: loss:7.280375
# epoch:[80/100]: loss:7.937302
# epoch:[90/100]: loss:6.867029
# epoch:[100/100]: loss:6.311531
# Finished Mapping!
# Setup: 0.08125011300035112
# Get subset samples: 0.0022136862633124112
# Run model: 0.01600086584672075
# Reconstruction loss: 0.00018670302337947458
# Aligned loss: 0.0002478180299658561
# F-cross loss: 2.1890826695501648e-05
# F-inv-cross loss: 1.9460463378588125e-05
# Step: 0.05821485040333452
# Output: 0.043076935999124544
# Total: 0.20123232385626277
# ---------------------------------
# ComManDo Done!
# Distance: 0.05144378299883101
# Correspondence: 3.9141454700002214
# Mapping: 23.202873918999103
# Total: 27.168463171998155

# %% [markdown]
# # UnionCom Unaligned

# %%
uc = ComManDo(project_mode='tsne')
uc_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:1.6447 alpha:0.6584
# epoch:[200/2000] err:1.0756 alpha:0.4405
# epoch:[300/2000] err:1.0785 alpha:0.4617
# epoch:[400/2000] err:1.0615 alpha:0.4804
# epoch:[500/2000] err:1.0320 alpha:0.4984
# epoch:[600/2000] err:0.9937 alpha:0.5168
# epoch:[700/2000] err:0.9436 alpha:0.5364
# epoch:[800/2000] err:0.8768 alpha:0.5580
# epoch:[900/2000] err:0.7976 alpha:0.5809
# epoch:[1000/2000] err:0.7222 alpha:0.6023
# epoch:[1100/2000] err:0.6627 alpha:0.6195
# epoch:[1200/2000] err:0.6187 alpha:0.6327
# epoch:[1300/2000] err:0.5845 alpha:0.6433
# epoch:[1400/2000] err:0.5559 alpha:0.6523
# epoch:[1500/2000] err:0.5306 alpha:0.6603
# epoch:[1600/2000] err:0.5071 alpha:0.6676
# epoch:[1700/2000] err:0.4846 alpha:0.6744
# epoch:[1800/2000] err:0.4634 alpha:0.6808
# epoch:[1900/2000] err:0.4434 alpha:0.6866
# epoch:[2000/2000] err:0.4250 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:0.728555, align_loss:0.036802
# epoch:[20/100]: loss:0.613879, align_loss:0.033592
# epoch:[30/100]: loss:0.575932, align_loss:0.035468
# epoch:[40/100]: loss:0.569644, align_loss:0.037567
# epoch:[50/100]: loss:0.550588, align_loss:0.038424
# epoch:[60/100]: loss:0.491329, align_loss:0.034379
# epoch:[70/100]: loss:0.500500, align_loss:0.038093
# epoch:[80/100]: loss:0.524532, align_loss:0.047239
# epoch:[90/100]: loss:0.487556, align_loss:0.035147
# epoch:[100/100]: loss:0.499817, align_loss:0.038110
# Done
# ---------------------------------
# ComManDo Done!
# Distance: 0.0990825050012063
# Correspondence: 4.010280339000019
# Mapping: 3.549226818000534
# Total: 7.658589662001759

# %% [markdown]
# # Figure Generation

# %%
dataset = [data1, data2]
labels = [np.array([type_func(j) for j in i]) for i in (type1,type2)]
params = {
    'dataset_names': ['Gene Expression', 'DNA Methylation'],
    'alg_results': [uc_data],
    'alg_names': ['UnionCom'],
}
generate_figure(cm, cm_data, dataset, labels, **params)
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:1.6447 alpha:0.6584
# epoch:[200/2000] err:1.0756 alpha:0.4405
# epoch:[300/2000] err:1.0785 alpha:0.4617
# epoch:[400/2000] err:1.0615 alpha:0.4804
# epoch:[500/2000] err:1.0320 alpha:0.4984
# epoch:[600/2000] err:0.9937 alpha:0.5168
# epoch:[700/2000] err:0.9436 alpha:0.5364
# epoch:[800/2000] err:0.8768 alpha:0.5580
# epoch:[900/2000] err:0.7976 alpha:0.5809
# epoch:[1000/2000] err:0.7222 alpha:0.6023
# epoch:[1100/2000] err:0.6627 alpha:0.6195
# epoch:[1200/2000] err:0.6187 alpha:0.6327
# epoch:[1300/2000] err:0.5845 alpha:0.6433
# epoch:[1400/2000] err:0.5559 alpha:0.6523
# epoch:[1500/2000] err:0.5306 alpha:0.6603
# epoch:[1600/2000] err:0.5071 alpha:0.6676
# epoch:[1700/2000] err:0.4846 alpha:0.6744
# epoch:[1800/2000] err:0.4634 alpha:0.6808
# epoch:[1900/2000] err:0.4434 alpha:0.6866
# epoch:[2000/2000] err:0.4250 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Performing NLMA
# epoch:[10/100]: loss:13.779474
# epoch:[20/100]: loss:12.303637
# epoch:[30/100]: loss:10.454706
# epoch:[40/100]: loss:9.678569
# epoch:[50/100]: loss:8.836480
# epoch:[60/100]: loss:8.106987
# epoch:[70/100]: loss:9.399151
# epoch:[80/100]: loss:7.568230
# epoch:[90/100]: loss:6.976367
# epoch:[100/100]: loss:7.000016
# Finished Mapping!
# Setup: 0.07645907499863824
# Get subset samples: 0.003296784133399342
# Run model: 0.015761243569977525
# Reconstruction loss: 0.00018749962668152876
# Aligned loss: 0.0002336065866317464
# F-cross loss: 2.3157779966519836e-05
# F-inv-cross loss: 2.0464219936305502e-05
# Step: 0.05764097411664504
# Output: 0.04223507299866469
# Total: 0.19585787803054094
# ---------------------------------
# ComManDo Done!
# Distance: 0.17139771100119106
# Correspondence: 3.982075193000128
# Mapping: 23.274140961999365
# Total: 27.427613866000684
# label transfer accuracy: 0.7366666666666667
# foscttm: 0.055211111111111114
#
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:1.6447 alpha:0.6584
# epoch:[200/2000] err:1.0756 alpha:0.4405
# epoch:[300/2000] err:1.0785 alpha:0.4617
# epoch:[400/2000] err:1.0615 alpha:0.4804
# epoch:[500/2000] err:1.0320 alpha:0.4984
# epoch:[600/2000] err:0.9937 alpha:0.5168
# epoch:[700/2000] err:0.9436 alpha:0.5364
# epoch:[800/2000] err:0.8768 alpha:0.5580
# epoch:[900/2000] err:0.7976 alpha:0.5809
# epoch:[1000/2000] err:0.7222 alpha:0.6023
# epoch:[1100/2000] err:0.6627 alpha:0.6195
# epoch:[1200/2000] err:0.6187 alpha:0.6327
# epoch:[1300/2000] err:0.5845 alpha:0.6433
# epoch:[1400/2000] err:0.5559 alpha:0.6523
# epoch:[1500/2000] err:0.5306 alpha:0.6603
# epoch:[1600/2000] err:0.5071 alpha:0.6676
# epoch:[1700/2000] err:0.4846 alpha:0.6744
# epoch:[1800/2000] err:0.4634 alpha:0.6808
# epoch:[1900/2000] err:0.4434 alpha:0.6866
# epoch:[2000/2000] err:0.4250 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Performing NLMA
# epoch:[10/100]: loss:13.824763
# epoch:[20/100]: loss:12.373669
# epoch:[30/100]: loss:10.482644
# epoch:[40/100]: loss:9.772143
# epoch:[50/100]: loss:8.988634
# epoch:[60/100]: loss:7.958990
# epoch:[70/100]: loss:8.697219
# epoch:[80/100]: loss:7.701922
# epoch:[90/100]: loss:7.866098
# epoch:[100/100]: loss:6.956697
# Finished Mapping!
# Setup: 0.06800825200116378
# Get subset samples: 0.0032044599366539235
# Run model: 0.01463501461328633
# Reconstruction loss: 0.0001780591599466182
# Aligned loss: 0.00023403302998000679
# F-cross loss: 2.0887066621071427e-05
# F-inv-cross loss: 1.9363106633439506e-05
# Step: 0.05329464143667792
# Output: 0.03837948000000324
# Total: 0.17797419035096634
# ---------------------------------
# ComManDo Done!
# Distance: 0.07912357500026701
# Correspondence: 4.0071104999988165
# Mapping: 21.588547847999507
# Total: 25.67478192299859
# label transfer accuracy: 0.7733333333333333
# foscttm: 0.2029
#
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:1.6447 alpha:0.6584
# epoch:[200/2000] err:1.0756 alpha:0.4405
# epoch:[300/2000] err:1.0785 alpha:0.4617
# epoch:[400/2000] err:1.0615 alpha:0.4804
# epoch:[500/2000] err:1.0320 alpha:0.4984
# epoch:[600/2000] err:0.9937 alpha:0.5168
# epoch:[700/2000] err:0.9436 alpha:0.5364
# epoch:[800/2000] err:0.8768 alpha:0.5580
# epoch:[900/2000] err:0.7976 alpha:0.5809
# epoch:[1000/2000] err:0.7222 alpha:0.6023
# epoch:[1100/2000] err:0.6627 alpha:0.6195
# epoch:[1200/2000] err:0.6187 alpha:0.6327
# epoch:[1300/2000] err:0.5845 alpha:0.6433
# epoch:[1400/2000] err:0.5559 alpha:0.6523
# epoch:[1500/2000] err:0.5306 alpha:0.6603
# epoch:[1600/2000] err:0.5071 alpha:0.6676
# epoch:[1700/2000] err:0.4846 alpha:0.6744
# epoch:[1800/2000] err:0.4634 alpha:0.6808
# epoch:[1900/2000] err:0.4434 alpha:0.6866
# epoch:[2000/2000] err:0.4250 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Performing NLMA
# epoch:[10/100]: loss:13.594101
# epoch:[20/100]: loss:11.572464
# epoch:[30/100]: loss:12.883839
# epoch:[40/100]: loss:9.459291
# epoch:[50/100]: loss:8.717750
# epoch:[60/100]: loss:7.910768
# epoch:[70/100]: loss:7.280375
# epoch:[80/100]: loss:7.937302
# epoch:[90/100]: loss:6.867029
# epoch:[100/100]: loss:6.311531
# Finished Mapping!
# Setup: 0.07232068600023922
# Get subset samples: 0.0021441427899965976
# Run model: 0.015233267076637276
# Reconstruction loss: 0.00018215113671734193
# Aligned loss: 0.0002427561566825413
# F-cross loss: 2.157925324354437e-05
# F-inv-cross loss: 1.936957665141866e-05
# Step: 0.05527291335004217
# Output: 0.038775951999923564
# Total: 0.18421281734013367
# ---------------------------------
# ComManDo Done!
# Distance: 0.07647958499910601
# Correspondence: 4.083102103999408
# Mapping: 22.052690702999826
# Total: 26.21227239199834
# label transfer accuracy: 0.8733333333333333
# foscttm: 0.03537777777777778
#
# label transfer accuracy: 0.8733333333333333
# foscttm: 0.03537777777777778
# label transfer accuracy: 0.9666666666666667
# foscttm: 0.009711111111111111
