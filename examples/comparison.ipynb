# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np

from commando import ComManDo
from unioncom import UnionCom
# Out:
# 2021-11-30 14:04:02.650968: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-11-30 14:04:02.651003: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
data1 = np.loadtxt("./UnionCom/simu1/domain1.txt")
data2 = np.loadtxt("./UnionCom/simu1/domain2.txt")
type1 = np.loadtxt("./UnionCom/simu1/type1.txt")
type2 = np.loadtxt("./UnionCom/simu1/type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)

# %% [markdown]
# # UnionCom

# %%
uc = UnionCom.UnionCom()
uc_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# use device: cpu
# epoch:[100/2000] err:1.6781 alpha:0.6718
# epoch:[200/2000] err:1.0728 alpha:0.4390
# epoch:[300/2000] err:1.0786 alpha:0.4615
# epoch:[400/2000] err:1.0618 alpha:0.4802
# epoch:[500/2000] err:1.0323 alpha:0.4982
# epoch:[600/2000] err:0.9942 alpha:0.5166
# epoch:[700/2000] err:0.9442 alpha:0.5362
# epoch:[800/2000] err:0.8775 alpha:0.5578
# epoch:[900/2000] err:0.7984 alpha:0.5807
# epoch:[1000/2000] err:0.7229 alpha:0.6021
# epoch:[1100/2000] err:0.6632 alpha:0.6193
# epoch:[1200/2000] err:0.6191 alpha:0.6326
# epoch:[1300/2000] err:0.5848 alpha:0.6432
# epoch:[1400/2000] err:0.5562 alpha:0.6522
# epoch:[1500/2000] err:0.5309 alpha:0.6602
# epoch:[1600/2000] err:0.5073 alpha:0.6676
# epoch:[1700/2000] err:0.4849 alpha:0.6744
# epoch:[1800/2000] err:0.4636 alpha:0.6807
# epoch:[1900/2000] err:0.4436 alpha:0.6865
# epoch:[2000/2000] err:0.4252 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:0.728555, align_loss:0.036802
# epoch:[20/100]: loss:0.613879, align_loss:0.033592
# epoch:[30/100]: loss:0.575932, align_loss:0.035468
# epoch:[40/100]: loss:0.569644, align_loss:0.037567
# epoch:[50/100]: loss:0.550588, align_loss:0.038424
# epoch:[60/100]: loss:0.491329, align_loss:0.034379
# epoch:[70/100]: loss:0.500500, align_loss:0.038093
# epoch:[80/100]: loss:0.524532, align_loss:0.047239
# epoch:[90/100]: loss:0.487556, align_loss:0.035147
# epoch:[100/100]: loss:0.499817, align_loss:0.038110
# Done
# ---------------------------------
# unionCom Done!
# time: 3.2947990894317627 seconds

# %%
uc.test_LabelTA(uc_data, [type1,type2])
uc.Visualize([data1,data2], uc_data, [type1,type2], mode='PCA')
# Out:
# label transfer accuracy of data1:
# 0.9666666666666667
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # ComManDo

# %%
if True:
    cm = ComManDo(project_mode='nlma', distance_mode='geodesic', epoch_pd=2000)
    cm_data = cm.fit_transform(dataset=[data1,data2])
else:
    cm = ComManDo(project_mode='nlma', distance_mode='euclidean', epoch_pd=2000)
    cm_data = cm.fit_transform(dataset=[data1[:3],data2[:3]])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (300, 1000)
# Dataset 1: (300, 500)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:1.6447 alpha:0.6584
# epoch:[200/2000] err:1.0756 alpha:0.4405
# epoch:[300/2000] err:1.0785 alpha:0.4617
# epoch:[400/2000] err:1.0615 alpha:0.4804
# epoch:[500/2000] err:1.0320 alpha:0.4984
# epoch:[600/2000] err:0.9937 alpha:0.5168
# epoch:[700/2000] err:0.9436 alpha:0.5364
# epoch:[800/2000] err:0.8768 alpha:0.5580
# epoch:[900/2000] err:0.7976 alpha:0.5809
# epoch:[1000/2000] err:0.7222 alpha:0.6023
# epoch:[1100/2000] err:0.6627 alpha:0.6195
# epoch:[1200/2000] err:0.6187 alpha:0.6327
# epoch:[1300/2000] err:0.5845 alpha:0.6433
# epoch:[1400/2000] err:0.5559 alpha:0.6523
# epoch:[1500/2000] err:0.5306 alpha:0.6603
# epoch:[1600/2000] err:0.5071 alpha:0.6676
# epoch:[1700/2000] err:0.4846 alpha:0.6744
# epoch:[1800/2000] err:0.4634 alpha:0.6808
# epoch:[1900/2000] err:0.4434 alpha:0.6866
# epoch:[2000/2000] err:0.4250 alpha:0.6918
# Finished Matching!
# ---------------------------------
# Performing NLMA
# Applying Coefficients
# Computing Laplacian
# Calculating eigenvectors
# Perfoming mapping
# ---------------------------------
# ComManDo Done!
# Distance: 0.05666886200015142
# Correspondence: 3.8561236090008606
# Mapping: 0.26537793399984366
# Total: 4.178170405000856

# %%
cm.test_LabelTA(cm_data, [type1,type2])
cm.Visualize([data1,data2], cm_data, [type1,type2], mode='PCA')
# Out:
# label transfer accuracy of data1:
# 0.4666666666666667
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
