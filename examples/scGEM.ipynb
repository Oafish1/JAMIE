# %%
# %load_ext autoreload
# %autoreload 2

# %%
from commando import ComManDo
import numpy as np
# Out:
# 2022-01-04 21:29:34.485603: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-01-04 21:29:34.485644: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
data1 = np.loadtxt("./UnionCom/scGEM/GeneExpression.txt")
data2 = np.loadtxt("./UnionCom/scGEM/DNAmethylation.txt")
type1 = np.loadtxt("./UnionCom/scGEM/type1.txt")
type2 = np.loadtxt("./UnionCom/scGEM/type2.txt")
type1 = type1.astype(np.int)
type2 = type2.astype(np.int)

# %% [markdown]
# # ComManDo

# %%
cm = ComManDo()
cm_data = cm.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (177, 34)
# Dataset 1: (177, 27)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:3.6545 alpha:1.0122
# epoch:[200/2000] err:2.9233 alpha:1.1805
# epoch:[300/2000] err:2.0462 alpha:1.3132
# epoch:[400/2000] err:1.6937 alpha:1.3747
# epoch:[500/2000] err:1.5626 alpha:1.4014
# epoch:[600/2000] err:1.5047 alpha:1.4145
# epoch:[700/2000] err:1.4725 alpha:1.4224
# epoch:[800/2000] err:1.4507 alpha:1.4282
# epoch:[900/2000] err:1.4341 alpha:1.4329
# epoch:[1000/2000] err:1.4207 alpha:1.4369
# epoch:[1100/2000] err:1.4093 alpha:1.4405
# epoch:[1200/2000] err:1.3993 alpha:1.4436
# epoch:[1300/2000] err:1.3907 alpha:1.4463
# epoch:[1400/2000] err:1.3833 alpha:1.4488
# epoch:[1500/2000] err:1.3769 alpha:1.4510
# epoch:[1600/2000] err:1.3714 alpha:1.4530
# epoch:[1700/2000] err:1.3668 alpha:1.4549
# epoch:[1800/2000] err:1.3629 alpha:1.4565
# epoch:[1900/2000] err:1.3594 alpha:1.4580
# epoch:[2000/2000] err:1.3564 alpha:1.4593
# Finished Matching!
# ---------------------------------
# Performing NLMA
# epoch:[10/100]: loss:3.192651
# epoch:[20/100]: loss:2.564955
# epoch:[30/100]: loss:2.521365
# epoch:[40/100]: loss:2.662161
# epoch:[50/100]: loss:2.160152
# epoch:[60/100]: loss:2.219327
# epoch:[70/100]: loss:2.084839
# epoch:[80/100]: loss:1.873590
# epoch:[90/100]: loss:1.904803
# epoch:[100/100]: loss:2.110644
# Finished Mapping!
# Setup: 0.0035410700002103113
# Get subset samples: 0.00674258975997418
# Run model: 0.08700753102996714
# Reconstruction loss: 0.00010012664997702814
# Aligned loss: 0.003234478620001937
# F-cross loss: 2.3735644981570657e-05
# Step: 0.08493504564999058
# Output: 0.0016625229995952395
# Total: 0.187247100354698
# ---------------------------------
# ComManDo Done!
# Distance: 0.02598332500019751
# Correspondence: 202.24335117700002
# Mapping: 18.2143982409998
# Total: 220.48373274300002

# %%
cm.test_LabelTA(cm_data, [type1,type2])
cm.test_closer(cm_data)
cm.Visualize([data1,data2], cm_data, [type1,type2], mode='PCA')
# Out:
# label transfer accuracy of data1:
# 0.847457627118644
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# foscttm: 0.12769319161160586

# %% [markdown]
# # UnionCom

# %%
uc = ComManDo(project_mode='tsne')
uc_data = uc.fit_transform(dataset=[data1,data2])
# Out:
# use random seed: 666
# Shape of Raw data
# Dataset 0: (177, 34)
# Dataset 1: (177, 27)
# Device: cpu
# ---------------------------------
# Find correspondence between Dataset 1 and Dataset 2
# epoch:[100/2000] err:3.6545 alpha:1.0122
# epoch:[200/2000] err:2.9233 alpha:1.1805
# epoch:[300/2000] err:2.0462 alpha:1.3132
# epoch:[400/2000] err:1.6937 alpha:1.3747
# epoch:[500/2000] err:1.5626 alpha:1.4014
# epoch:[600/2000] err:1.5047 alpha:1.4145
# epoch:[700/2000] err:1.4725 alpha:1.4224
# epoch:[800/2000] err:1.4507 alpha:1.4282
# epoch:[900/2000] err:1.4341 alpha:1.4329
# epoch:[1000/2000] err:1.4207 alpha:1.4369
# epoch:[1100/2000] err:1.4093 alpha:1.4405
# epoch:[1200/2000] err:1.3993 alpha:1.4436
# epoch:[1300/2000] err:1.3907 alpha:1.4463
# epoch:[1400/2000] err:1.3833 alpha:1.4488
# epoch:[1500/2000] err:1.3769 alpha:1.4510
# epoch:[1600/2000] err:1.3714 alpha:1.4530
# epoch:[1700/2000] err:1.3668 alpha:1.4549
# epoch:[1800/2000] err:1.3629 alpha:1.4565
# epoch:[1900/2000] err:1.3594 alpha:1.4580
# epoch:[2000/2000] err:1.3564 alpha:1.4593
# Finished Matching!
# ---------------------------------
# Begin finding the embedded space
# epoch:[10/100]: loss:1.936294, align_loss:0.121671
# epoch:[20/100]: loss:1.407675, align_loss:0.082441
# epoch:[30/100]: loss:1.237158, align_loss:0.085172
# epoch:[40/100]: loss:1.326588, align_loss:0.087727
# epoch:[50/100]: loss:1.305145, align_loss:0.080713
# epoch:[60/100]: loss:1.076542, align_loss:0.079094
# epoch:[70/100]: loss:1.154314, align_loss:0.070750
# epoch:[80/100]: loss:1.197445, align_loss:0.078370
# epoch:[90/100]: loss:1.189893, align_loss:0.080868
# epoch:[100/100]: loss:1.116361, align_loss:0.075028
# Done
# ---------------------------------
# ComManDo Done!
# Distance: 0.16462759100022595
# Correspondence: 241.31674956000006
# Mapping: 23.601777687999856
# Total: 265.08315483900014

# %%
uc.test_LabelTA(uc_data, [type1,type2])
uc.test_closer(uc_data)
uc.Visualize([data1,data2], uc_data, [type1,type2], mode='PCA')
# Out:
# label transfer accuracy of data1:
# 0.5875706214689266
# foscttm: 0.23286731143668804
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
